# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import graph_objs as go
from scipy.stats import pearsonr
from statsmodels.tsa.arima_model import ARIMA
from fbprophet import Prophet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from datetime import timedelta

import warnings
warnings.filterwarnings('ignore')

import logging
logging.getLogger('fbprophet').setLevel(logging.WARNING)

# %matplotlib inline
init_notebook_mode(connected = True)

# %%
class PPPredictor:
    
    def __init__(self):
        self.model = Prophet()
    
    def prepare_data(self, data, actual_date):
        df = data.copy()
        df.index = pd.to_datetime(df['Date'])
        df.drop(['Date'], axis=1, inplace=True)
        for col in df.columns:
            df[col].interpolate(method='time', inplace=True)
        df.index = pd.to_datetime(df.index)
        return df[df.index <= pd.to_datetime(actual_date)]

    def fit(self, prepared_data, use_text_model=False):
        prepared_df = pd.DataFrame({'ds': prepared_data.index, 'y': prepared_data['PPSpotAvgPrice']}).reset_index().drop(['Date'], axis=1)
        self.model.fit(prepared_df)
        return self.model
    
    def predict(self, date):
        date = pd.to_datetime(date)
        forecast = self.model.predict(pd.DataFrame({'ds': [date]}))
        return forecast['yhat'][0]

# %%
 def get_next_monday(df, date):
    first = True
    while len(df[df.index == str(date).split()[0]]) == 0:
        if first:
            date += timedelta(days=((7 - date.weekday()) % 7))
            first = False
        else:
            date += timedelta(7)
    return date

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def test_sol(date):
    df = pd.read_csv('./data/retrieved_data.csv')
    ppp = PPPredictor()
    prepared = ppp.prepare_data(df, date)
    ppp.fit(prepared)
    
    df.index = pd.to_datetime(df['Date'])
    df.drop(['Date'], axis=1, inplace=True)
    for col in df.columns:
        df[col].interpolate(method='time', inplace=True)
    
    start = pd.to_datetime(date) + timedelta(3 * 30)
    end = pd.to_datetime(date) + timedelta(4 * 30)
    pred = []
    actual = []
    for dt in pd.date_range(start, end, freq='W'):
        pred.append(ppp.predict(str(dt).split()[0]))
        actual_dt = get_next_monday(df, dt)
        right_val = df[df.index == str(actual_dt).split()[0]]['PPSpotAvgPrice'].iloc[0]
        actual.append(right_val)
    print('MAPE for {}: {:.2f}%'.format(date, mean_absolute_percentage_error(pred, actual)))

# %%
for dt in pd.date_range(start=pd.to_datetime('2013-12-01'), 
                        end=pd.to_datetime('2018-07-01'), freq='M'):
    test_sol(str(dt).split()[0])
# Out:
# MAPE for 2013-12-31: 26.24%
# MAPE for 2014-01-31: 23.48%
# MAPE for 2014-02-28: 32.62%
# MAPE for 2014-03-31: 11.96%
# MAPE for 2014-04-30: 10.26%
# MAPE for 2014-05-31: 6.99%
# MAPE for 2014-06-30: 11.23%
# MAPE for 2014-07-31: 13.65%
# MAPE for 2014-08-31: 17.79%
# MAPE for 2014-09-30: 22.17%
# MAPE for 2014-10-31: 15.65%
# MAPE for 2014-11-30: 3.12%
# MAPE for 2014-12-31: 27.55%
# MAPE for 2015-01-31: 54.70%
# MAPE for 2015-02-28: 65.78%
# MAPE for 2015-03-31: 45.31%
# MAPE for 2015-04-30: 22.76%
# MAPE for 2015-05-31: 10.54%
# MAPE for 2015-06-30: 22.29%
# MAPE for 2015-07-31: 17.63%
# MAPE for 2015-08-31: 17.99%
# MAPE for 2015-09-30: 16.49%
# MAPE for 2015-10-31: 11.26%
# MAPE for 2015-11-30: 54.29%
# MAPE for 2015-12-31: 43.75%
# MAPE for 2016-01-31: 18.47%
# MAPE for 2016-02-29: 3.56%
# MAPE for 2016-03-31: 3.40%
# MAPE for 2016-04-30: 1.32%
# MAPE for 2016-05-31: 8.98%
# MAPE for 2016-06-30: 17.54%
# MAPE for 2016-07-31: 26.42%
# MAPE for 2016-08-31: 30.91%
# MAPE for 2016-09-30: 31.63%
# MAPE for 2016-10-31: 31.22%
# MAPE for 2016-11-30: 5.11%
# MAPE for 2016-12-31: 14.43%
# MAPE for 2017-01-31: 26.70%
# MAPE for 2017-02-28: 29.85%
# MAPE for 2017-03-31: 27.94%
# MAPE for 2017-04-30: 19.97%
# MAPE for 2017-05-31: 9.95%
# MAPE for 2017-06-30: 8.70%
# MAPE for 2017-07-31: 3.32%
# MAPE for 2017-08-31: 13.60%
# MAPE for 2017-09-30: 23.91%
# MAPE for 2017-10-31: 20.98%
# MAPE for 2017-11-30: 12.69%
# MAPE for 2017-12-31: 3.08%
# MAPE for 2018-01-31: 1.28%
# MAPE for 2018-02-28: 1.26%
# MAPE for 2018-03-31: 3.85%
# MAPE for 2018-04-30: 1.64%
# MAPE for 2018-05-31: 2.17%
# MAPE for 2018-06-30: 9.78%

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

f = open("news-links.txt", 'r')

db = pd.DataFrame(columns=['SiteName', 'Text', 'Date'])


links = f.readlines()

for link in links:
    if link.replace(' ', '') == '':
        continue
    print('link -> ', link)
    text = requests.get(link[:-1]).text
    # print(text)
    soup = BeautifulSoup(text, "html.parser")
    # print(soup.prettify())
    # print(soup)
    texts = soup.findAll("div", "StandardArticleBody_body")[0].text
    #print(texts)
    t = soup.find("div", "ArticleHeader_date").text
    raw_date = t[:t.find('/')]
    date = datetime.strptime(raw_date, "%B %d, %Y ")
    article_date = datetime.strftime(date, "%d-%m-%Y")
    print(article_date)
    db = db.append({'SiteName': "https://www.reuters.com",'Text': texts,'Date': article_date}, ignore_index=True)

db.to_csv("./data/retrieved_articles.csv")
# Out:
# link ->  https://www.reuters.com/article/brief-exxonmobil-considers-polypropylene/brief-exxonmobil-considers-polypropylene-production-expansion-along-u-s-gulf-coast-idUSFWN1R20N2
#
# 20-03-2018
# link ->  https://www.reuters.com/article/brief-jacobs-awarded-contract-to-complet/brief-jacobs-awarded-contract-to-complete-feasibility-study-for-expansion-of-borealis-polypropylene-plants-in-belgium-idUSFWN1Q30YY
#
# 13-02-2018
# link ->  https://www.reuters.com/article/brief-srf-commissions-first-phase-of-bi/brief-srf-commissions-first-phase-of-bi-axially-oriented-polypropylene-film-line-metallizer-project-idUSFWN1OT032
#
# 29-12-2017
# link ->  https://www.reuters.com/article/brief-braskem-approves-construction-of-p/brief-braskem-approves-construction-of-polypropylene-production-line-idUSFWN1JJ0F8
#
# 22-06-2017
# link ->  https://www.reuters.com/article/brief-inter-pipeline-to-build-canadas-fi/brief-inter-pipeline-to-build-canadas-first-integrated-propane-dehydrogenation-and-polypropylene-complex-idUSFWN1OI0K7
#
# 18-12-2017
# link ->  https://www.reuters.com/article/max-india-chemicals-sale/max-india-in-talks-to-sell-polypropylene-business-report-idUSL3E8FN1UI20120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/us-dowchemical-divestment/dow-to-sell-polypropylene-catalyst-business-to-w-r-grace-idUSBRE99A0DJ20131011
#
# 11-10-2013
# link ->  https://www.reuters.com/article/petroliam-lyondell/petronas-picks-lyondellbasell-polypropylene-technology-for-rapid-plant-idUSL3N0U33T320141219
#
# 19-12-2014
# link ->  https://www.reuters.com/article/us-max-india-chemicals-sale/max-india-in-talks-to-sell-polypropylene-business-report-idUSBRE83M04020120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/braskem-investment/braskem-to-invest-675-mln-in-6th-u-s-based-polypropylene-plant-idUSL1N1JJ0AF
#
# 22-06-2017
# link ->  https://www.reuters.com/article/dowchemical-divestment/update-1-dow-to-sell-polypropylene-catalyst-business-to-w-r-grace-idUSL4N0I12MW20131011
#
# 11-10-2013
# link ->  https://www.reuters.com/article/china-futures-dalian/chinas-dalian-raises-transaction-fees-for-iron-ore-polypropylene-futures-idUSB9N17O03D
#
# 25-04-2016
# link ->  https://www.reuters.com/article/dowchemical-divestment/dow-to-sell-polypropylene-licensing-business-to-w-r-grace-for-500-mln-idUSL4N0I12MB20131011
#
# 11-10-2013
# link ->  https://www.reuters.com/article/india-press/india-press-max-india-to-sell-polypropylene-business-economic-times-idUSL3E8FN1K520120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/idUSFWN17C01K
#
# 11-04-2016
# link ->  https://www.reuters.com/article/idUSFWN17C01L
#
# 11-04-2016
# link ->  https://www.reuters.com/article/china-exxonmobil-chemicals/exxon-mobil-to-build-1-2-mln-tpy-ethylene-plant-in-chinas-guangdong-idUSB9N1VI01E
#
# 06-09-2018
# link ->  https://www.reuters.com/article/brief-izoblok-signs-around-eur-178-mln-d/brief-izoblok-signs-around-eur-17-8-mln-deal-with-czech-based-company-idUSFWN1SE10F
#
# 07-05-2018
# link ->  https://www.reuters.com/article/total-algeria/rpt-update-2-frances-total-signs-1-5-bln-sonatrach-deal-for-algerian-project-idUSL8N1SI4MC
#
# 11-05-2018
# link ->  https://www.reuters.com/article/exxon-mobil-plastic/exxon-eyes-gulf-of-mexico-plastics-plant-idUSL3N1R24KI
#
# 20-03-2018
# link ->  https://www.reuters.com/article/us-total-algeria/frances-total-signs-1-5-billion-sonatrach-deal-for-algerian-project-idUSKBN1IC1AB
#
# 11-05-2018
# link ->  https://www.reuters.com/article/us-total-algeria/frances-total-signs-1-5-billion-sonatrach-deal-for-algerian-project-idUSKBN1IC1AB
#
# 11-05-2018
# link ->  https://www.reuters.com/article/turkmenistan-chemicals/turkmenistan-opens-3-4-bln-chemicals-plant-idUSL8N1WX1IP
#
# 17-10-2018
# link ->  https://www.reuters.com/article/us-borealis-belgium/austrias-borealis-to-build-1-billion-euro-plant-in-belgium-idUSKCN1MH0SE
#
# 07-10-2018
# link ->  https://www.reuters.com/article/braskem-petrobras-naphtha/brazils-braskem-to-talk-new-naphtha-contract-with-petrobras-ceo-idUSL1N1SH123
#
# 10-05-2018
# link ->  https://www.reuters.com/article/emirates-pakistan-wto/uae-goes-to-wto-over-pakistans-duties-on-bopp-food-packaging-idUSL8N1PO5M8
#
# 29-01-2018
# link ->  https://www.reuters.com/article/us-borealis-belgium/austrias-borealis-to-build-1-billion-euro-plant-in-belgium-idUSKCN1MH0SE
#
# 07-10-2018
# link ->  https://www.reuters.com/article/braskem-petrobras-naphtha/update-1-brazils-braskem-to-talk-new-naphtha-contract-with-petrobras-ceo-idUSL1N1SH1T9
#
# 10-05-2018
# link ->  https://www.reuters.com/article/us-turkmenistan-ports/turkmenistan-seeks-to-tap-into-east-west-cargo-flows-with-new-seaport-idUSKBN1I31VJ
#
# 02-05-2018
# link ->  https://www.reuters.com/article/mideast-stocks/mideast-stocks-saudi-recovers-some-losses-most-of-gulf-inches-up-idUSL3N1WV2LJ
#
# 15-10-2018
# link ->  https://www.reuters.com/article/us-manucor-m-a-pillarstone/pillarstone-buys-italys-manucor-in-debt-restructuring-deal-idUSKBN1I40ZA
#
# 03-05-2018
# link ->  https://www.reuters.com/article/us-turkmenistan-ports/turkmenistan-seeks-to-tap-into-east-west-cargo-flows-with-new-seaport-idUSKBN1I31VJ
#
# 02-05-2018
# link ->  https://www.reuters.com/article/us-manucor-m-a-pillarstone/pillarstone-buys-italys-manucor-in-debt-restructuring-deal-idUSKBN1I40ZA
#
# 03-05-2018
# link ->  https://www.reuters.com/article/orpic-bond/omans-orpic-in-talks-for-potential-debut-dollar-bond-sale-sources-idUSL8N1Q92T7
#
# 19-02-2018
# link ->  https://www.reuters.com/article/us-canada-inter-us-petrochemicals/inter-pipeline-to-build-2-7-billion-alberta-petrochemical-plant-idUSKBN1EC2L9
#
# 18-12-2017
# link ->  https://www.reuters.com/article/us-canada-inter-us-petrochemicals/inter-pipeline-to-build-2-7-billion-alberta-petrochemical-plant-idUSKBN1EC2L9
#
# 18-12-2017
# link ->  https://www.reuters.com/article/us-sonatrach-exxon-mobil/sonatrach-to-buy-exxonmobils-augusta-oil-refinery-in-sicily-idUSKBN1IA2R4
#
# 09-05-2018
# link ->  https://www.reuters.com/article/us-total-petrochemicals-bayport/total-finalizes-plans-to-expand-texas-bayport-polymers-in-petrochems-push-idUSKCN1M51Y5
#
# 25-09-2018
# link ->  https://www.reuters.com/article/us-sonatrach-exxon-mobil/sonatrach-to-buy-exxonmobils-augusta-oil-refinery-in-sicily-idUSKBN1IA2R4
#
# 09-05-2018
# link ->  https://www.reuters.com/article/s-oil-results/update-1-s-oil-sees-q4-refining-margins-rise-on-seasonal-demand-tight-supply-idUSL3N1X6193
#
# 26-10-2018
# link ->  https://www.reuters.com/article/us-russia-sibur-asia/russias-sibur-says-new-gas-chemical-complex-will-cost-up-to-8-billion-idUSKCN1J41LN
#
# 08-06-2018
# link ->  https://www.reuters.com/article/us-russia-sibur-asia/russias-sibur-says-new-gas-chemical-complex-will-cost-up-to-8-billion-idUSKCN1J41LN
#
# 08-06-2018
# link ->  https://www.reuters.com/article/energy-socar/azeri-socar-to-supply-its-new-turkish-refinery-with-third-party-oil-idUSL8N1XJ7GI
#
# 09-11-2018
# link ->  https://www.reuters.com/article/us-china-exxonmobil-chemicals/exxonmobil-latest-foreign-major-to-invest-in-petchem-plant-lng-terminal-in-china-idUSKCN1LL38Y
#
# 06-09-2018
# link ->  https://www.reuters.com/article/us-kuwait-canada-petchems/kuwaits-pic-signs-contract-with-u-s-jacobs-for-plant-in-canada-idUSKBN1D409K
#
# 04-11-2017
# link ->  https://www.reuters.com/article/us-malawi-farming-storage/for-malawis-farmers-facing-harvest-pests-the-solutions-in-the-bag-idUSKCN1IP17B
#
# 24-05-2018
# link ->  https://www.reuters.com/article/mideast-stocks/mideast-stocks-saudi-rebounds-from-khashoggi-slide-as-institutions-buy-idUSL3N1WV3RI
#
# 15-10-2018
# link ->  https://www.reuters.com/article/us-china-exxonmobil-chemicals/exxonmobil-latest-foreign-major-to-invest-in-petchem-plant-lng-terminal-in-china-idUSKCN1LL38Y
#
# 06-09-2018
# link ->  https://www.reuters.com/article/us-pakistan-engro/in-shift-pakistani-giant-engro-to-bet-big-on-rising-middle-class-idUSKCN1LU039
#
# 14-09-2018
# link ->  https://www.reuters.com/article/us-malawi-farming-storage/for-malawis-farmers-facing-harvest-pests-the-solutions-in-the-bag-idUSKCN1IP17B
#
# 24-05-2018
# link ->  https://www.reuters.com/article/suez-lyondellbasell/suez-lyondellbasell-in-plastics-recycling-jv-idUSL8N1NX3D2
#
# 27-11-2017
# link ->  https://www.reuters.com/article/us-lyondell-plant/lyondell-weighs-building-2-billion-chemical-plant-media-report-idUSKBN1CU2IG
#
# 25-10-2017
# link ->  https://www.reuters.com/article/india-press/india-press-chryscapital-blackstone-in-race-to-buy-stake-in-intas-pharma-economic-times-idUSL3E8FN1LI20120423
# 23-04-2012
# link ->  https://www.reuters.com/article/dowchemical-assetsales/dow-chemical-looking-to-raise-1-5-billion-from-asset-sales-idUSL3N0C62JS20130314
#
# 14-03-2013
# link ->  https://www.reuters.com/article/us-tanzania-agriculture-foodsecurity/pest-proof-bags-and-bins-slim-tanzanias-lean-season-idUSKCN1LN1MJ
#
# 07-09-2018
# link ->  https://www.reuters.com/article/tanzania-agriculture-foodsecurity/corrected-feature-pest-proof-bags-and-bins-slim-tanzanias-lean-season-idUSL5N1UM7PP
#
# 07-09-2018
# link ->  https://www.reuters.com/article/dowchemical-assetsales/update-1-dow-chemical-looking-to-raise-1-5-bln-from-asset-sales-idUSL3N0C62LU20130314
#
# 14-03-2013
# link ->  https://www.reuters.com/article/idUSFWN1C30LG
#
# 27-09-2016
# link ->  https://www.reuters.com/article/india-press/india-press-reliance-industries-to-build-towers-for-4g-ops-economic-times-idUSL3E8FN1L720120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/china-futures-dalian/chinas-dalian-exchange-raises-transaction-fees-for-iron-ore-coking-coal-idUSB9N17O03X
#
# 26-04-2016
# link ->  https://www.reuters.com/article/idUSFWN1C60T6
#
# 30-09-2016
# link ->  https://www.reuters.com/article/brief-chinas-dalian-commodity-exchange-t/brief-chinas-dalian-commodity-exchange-to-cut-transaction-fees-on-iron-ore-coking-coal-coke-pp-futures-idUSB9N1H402X
#
# 12-04-2017
# link ->  https://www.reuters.com/article/sjs-ma-lyondell/lyondellbasell-to-buy-indian-ppc-maker-in-automotive-push-idUSL3N10L2RA20150810
#
# 10-08-2015
# link ->  https://www.reuters.com/article/brief-china-resources-double-crane-pharm/brief-china-resources-double-crane-pharma-sub-subsidiary-receives-gmp-certificate-idUSL3N1HK2VA
#
# 12-04-2017
# link ->  https://www.reuters.com/article/idUSL8N18Y0KK
#
# 06-06-2016
# link ->  https://www.reuters.com/article/idUSFWN0YR00H20150605
#
# 05-06-2015
# link ->  https://www.reuters.com/article/us-saudi-aramco-sabic-chemicals/saudi-aramco-sabic-plan-to-build-20-bln-oil-to-chemicals-complex-idUSKBN1DQ093
#
# 26-11-2017
# link ->  https://www.reuters.com/article/braskem-results-outlook/braskem-sees-brazil-plastics-market-growing-2-pct-in-2017-ceo-idUSE6N1CB02G
#
# 22-02-2017
# link ->  https://www.reuters.com/article/sinopecengineering-contract/sinopec-engineering-wins-contract-worth-1-85-bln-idUSL3N0EM2U220130610
#
# 10-06-2013
# link ->  https://www.reuters.com/article/india-press/india-press-gail-in-talks-for-jv-with-tokyo-gas-hindustan-times-idUSL3E8FN1UH20120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/cr-double-cran-brief/brief-china-resources-double-crane-pharmaceutical-unit-gets-gmp-certificate-idUSL3N1542OI
#
# 21-01-2016
# link ->  https://www.reuters.com/article/india-press/india-press-catholic-syrian-bank-plans-ipo-by-september-mint-idUSL3E8FN1U920120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/china-futures-dalian/chinas-dalian-exchange-to-adjust-transaction-fees-for-coking-coal-coke-iron-ore-idUSB9N17U00N
#
# 06-05-2016
# link ->  https://www.reuters.com/article/bayegan-saudi/turkeys-bayegan-saudi-advanced-petrochemical-to-set-up-plant-in-turkey-idUSL5E8G36YE20120503
#
# 03-05-2012
# link ->  https://www.reuters.com/article/brief-pembina-pipeline-corp-and-petroche/brief-pembina-pipeline-corp-and-petrochemical-industries-co-of-kuwait-establish-jv-idUSFWN1IH0TD
#
# 15-05-2017
# link ->  https://www.reuters.com/article/us-space-plastic/nasa-spacecraft-finds-plastic-ingredient-on-saturns-moon-titan-idUSBRE9900M320131001
#
# 01-10-2013
# link ->  https://www.reuters.com/article/india-press/india-press-capgemini-eyes-indian-it-services-market-business-standard-idUSL3E8FN1US20120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/lyondellbasell-orlen-poland/polish-basell-orlen-declares-force-majeure-on-some-products-idUSL8N1DI4E7
#
# 17-11-2016
# link ->  https://www.reuters.com/article/india-press/india-press-coal-india-may-pass-on-import-costs-financial-express-idUSL3E8FN1VA20120423
#
# 23-04-2012
# link ->  https://www.reuters.com/article/veolia-netherlands/update-2-veolia-buys-dutch-firm-akg-in-waste-recycling-push-idUSL5N1192MB20150903
#
# 03-09-2015
# link ->  https://www.reuters.com/article/us-usa-trade-china-products-factbox/factbox-china-tariffs-on-revised-list-of-16-billion-u-s-goods-idUSKBN1KU168
#
# 09-08-2018
# link ->  https://www.reuters.com/article/maxindia-unit/update-1-max-india-sells-unit-to-germanys-treofan-for-97mln-idUSL3E8KA4NU20120910
#
# 10-09-2012
# link ->  https://www.reuters.com/article/saudi-india/india-ends-saudi-chemicals-anti-dumping-measures-idUSL6E8C319H20120103
#
# 03-01-2012
# link ->  https://www.reuters.com/article/us-sabic-europe-strike/strike-at-sabic-dutch-chemical-plant-hits-output-idUSBRE91103Z20130202
#
# 02-02-2013
# link ->  https://www.reuters.com/article/gas-turkmenistan-loans/turkmenistan-gets-2-5-bln-in-japan-korea-loans-for-gas-complex-idUSL6N0OG1P620140530
#
# 30-05-2014
# link ->
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-13-7c93ecd1dd8a> in <module>()
#      15         continue
#      16     print('link -> ', link)
# ---> 17     text = requests.get(link[:-1]).text
#      18     # print(text)
#      19     soup = BeautifulSoup(text, "html.parser")
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     504             hooks=hooks,
#     505         )
# --> 506         prep = self.prepare_request(req)
#     507
#     508         proxies = proxies or {}
#
# /usr/lib/python3/dist-packages/requests/sessions.py in prepare_request(self, request)
#     447             auth=merge_setting(auth, self.auth),
#     448             cookies=merged_cookies,
# --> 449             hooks=merge_hooks(request.hooks, self.hooks),
#     450         )
#     451         return p
#
# /usr/lib/python3/dist-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     303
#     304         self.prepare_method(method)
# --> 305         self.prepare_url(url, params)
#     306         self.prepare_headers(headers)
#     307         self.prepare_cookies(cookies)
#
# /usr/lib/python3/dist-packages/requests/models.py in prepare_url(self, url, params)
#     377             error = error.format(to_native_string(url, 'utf8'))
#     378
# --> 379             raise MissingSchema(error)
#     380
#     381         if not host:
#
# MissingSchema: Invalid URL '': No schema supplied. Perhaps you meant http://?

# %%
# !pip install bs4 --user
# Out:
# Collecting bs4
# Requirement already satisfied: beautifulsoup4 in /home/rbkn99/.local/lib/python3.6/site-packages (from bs4) (4.6.3)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
